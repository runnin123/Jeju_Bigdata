# %% [markdown]
# <a href="https://colab.research.google.com/github/runnin123/Jeju_Bigdata/blob/master/Jeju_bigdata_2_79.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from google.cloud import bigquery
from tabulate import tabulate
import pandas as pd
import numpy as np
import sklearn
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from itertools import product

# 평가 메트릭
from sklearn.metrics import mean_squared_error, mean_absolute_error

# 통계
from scipy import stats
from scipy.stats import norm, skew #for some statistics

from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error

# %%
class Model:
    # Initialization method of the Model class about definition of the data
    # Input : split_data(Training/Test set of the independent value and the dependent value)
    #       : num(encoding_data)
    # Definition of the X
    def __init__(self, split_data, num):
        self.X_train = split_data[0]
        self.X_test = split_data[1]
        self.y_train = split_data[2]
        self.y_test = split_data[3]
        self.encoding_data = num

    # the rmsle between the actual value and predicted value
    def rmsle(self, y, pred): 
        log_y = np.log1p(y)
        log_pred = np.log1p(pred)
        squared_error = (log_y - log_pred)**2
        rmsle = np.sqrt(np.mean(squared_error))
        print('Test Data RMSLE: {0:.3f}'.format(rmsle))
        return round(rmsle, 3)

    # get best estimator and rmsle through GridSearchCV
    def best_params_model(self, model, params):
        cv_model = GridSearchCV(model, param_grid=params, scoring="neg_mean_squared_error", cv = 5)
        cv_model.fit(self.X_train, self.y_train)
        print("----", model.__class__.__name__, "----")
        print("GridSearchCV 최적 하이퍼 파라미터 :", cv_model.best_params_)

        eval_pred = cv_model.predict(self.X_test)
        eval_pred = np.expm1(eval_pred)
        rmsle_ = self.rmsle(self.y_test, eval_pred)

        return  cv_model.best_estimator_, rmsle_

    # Process about finding the ratio of XGB and GBM and LGB
    def get_model(self):
        xgb = XGBRegressor(random_state=0)
        gbm = GradientBoostingRegressor(random_state=0)
        lgb = LGBMRegressor(random_state=0)

        params = {'n_estimators': [1000, 2000]}

        models = [xgb, gbm, lgb]
        best_models = []
        rmsles = []
        
        for model in models:
            new_model = self.best_params_model(model, params)[0]
            new_rmsle = self.best_params_model(model, params)[1]
            best_models.append(new_model)
            rmsles.append(new_rmsle)

        self.xgb_reg = best_models[0]
        self.gbm_reg = best_models[1]
        self.lgb_reg = best_models[2]

        self.xgb_rmsle = rmsles[0]
        self.gbm_rmsle = rmsles[1]
        self.lgb_rmsle = rmsles[2]

        xgb_pred = self.xgb_reg.predict(self.X_test)
        xgb_pred = np.expm1(xgb_pred)

        gbm_pred = self.gbm_reg.predict(self.X_test)
        gbm_pred = np.expm1(gbm_pred)

        lgb_pred = self.lgb_reg.predict(self.X_test)
        lgb_pred = np.expm1(lgb_pred)

        pred = np.array([xgb_pred, gbm_pred, lgb_pred])
        pred = np.transpose(pred)

        rmsle_sum = self.xgb_rmsle + self.gbm_rmsle + self.lgb_rmsle

        self.xgb_per = self.xgb_rmsle / rmsle_sum
        self.gbm_per = self.gbm_rmsle / rmsle_sum
        self.lgb_per = self.lgb_rmsle / rmsle_sum
        
        final = xgb_pred*self.xgb_per + gbm_pred*self.gbm_per + lgb_pred*self.lgb_per
        print("--final RSMLE--")
        self.rmsle(self.y_test, final)

    # making the prediction template about 03/04/07/2020
    def make_temp(self):
        CARD_SIDO_NMs = self.encoding_data['CARD_SIDO_NM'].unique()
        STD_CLSS_NMs  = self.encoding_data['STD_CLSS_NM'].unique()
        HOM_SIDO_NMs  = self.encoding_data['HOM_SIDO_NM'].unique()
        AGEs          = self.encoding_data['AGE'].unique()
        SEX_CTGO_CDs  = self.encoding_data['SEX_CTGO_CD'].unique()
        FLCs          = self.encoding_data['FLC'].unique()
        nums          = self.encoding_data['num'].unique()
        years         = [2020]
        months        = [4, 7]

        comb_list = [CARD_SIDO_NMs, STD_CLSS_NMs,HOM_SIDO_NMs, AGEs, SEX_CTGO_CDs, FLCs, nums, years, months]
        temp = np.array(list(product(*comb_list)))

        train_features = self.encoding_data.drop(['CSTMR_CNT', 'AMT', 'CNT'], axis=1)
        tmp = pd.DataFrame(data=temp, columns=train_features.columns)

        return tmp

    # making submission
    def make_sub(self, temp):
        xgb_pred = self.xgb_reg.predict(temp)
        xgb_pred = np.expm1(xgb_pred)

        gbm_pred = self.gbm_reg.predict(temp)
        gbm_pred = np.expm1(gbm_pred)

        lgb_pred = self.lgb_reg.predict(temp)
        lgb_pred = np.expm1(lgb_pred)

        final_rmsle = xgb_pred*self.xgb_per + gbm_pred*self.gbm_per + lgb_pred*self.lgb_per

        temp['AMT'] = np.round(final_rmsle, 0)
        temp['REG_YYMM'] = temp['year']*100 + temp['month']
        temp = temp[['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM', 'AMT']]
        temp = temp.groupby(['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM']).sum().reset_index(drop = False)

        temp['CARD_SIDO_NM'] = encoders['CARD_SIDO_NM'].inverse_transform(temp['CARD_SIDO_NM'])
        temp['STD_CLSS_NM'] = encoders['STD_CLSS_NM'].inverse_transform(temp['STD_CLSS_NM'])

        return temp

# %%
def sampling(sido):
    df = data[data['CARD_SIDO_NM']==sido]
    df = df.sample(n=10000)
    return df

# %%
def grap_year(data):
    data = str(data)
    return int(data[:4])

def grap_month(data):
    data = str(data)
    return int(data[4:])

# %%
def data_pre(data):
    data = data.fillna('')
    data['year'] = data['REG_YYMM'].apply(lambda x: grap_year(x))
    data['month'] = data['REG_YYMM'].apply(lambda x: grap_month(x))
    data = data.drop(['REG_YYMM'], axis = 1)

    return data

# %%
def encoding(data):

    global encoders
    dtypes = data.dtypes
    encoders = {}
    for column in data.columns:
        if str(dtypes[column]) == 'object':
            encoder = LabelEncoder()
            encoder.fit(data[column])
            encoders[column] = encoder

    data_num = data.copy()

    for column in encoders.keys():
        encoder = encoders[column]
        data_num[column] = encoder.transform(data[column])

    return data_num

# %%
def split(data_num):
    split_data = []

    X_data, y_data = data_num.loc[:, data_num.columns != 'AMT'], data_num['AMT']
    X_data = X_data.drop(['CSTMR_CNT', 'CNT'], axis=1)
    X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.3, random_state=126, shuffle=True)
    y_train = np.log1p(y_train)
    
    return X_train, X_test, y_train, y_test

# %%
# train 데이터 불러오기
train = pd.read_csv('/content/drive/My Drive/Colab Notebooks/jeju/201901-202003.csv')
# 시도별 예측 데이터 프레임 생성을 위한 시도 리스트 생성
sido_list = train['CARD_SIDO_NM'].unique().tolist()

# %%
data_2004 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/jeju/202004.csv')

# %%
data_2003 = train[train['REG_YYMM'] == 202003]

# %%
from numpy import inf

def sido_diff(sido):
    df = train[train['CARD_SIDO_NM']==sido]
    df_19 = df[df['REG_YYMM']==201903]
    df_20 = df[df['REG_YYMM']==201904]
    diff = pd.concat([df_19.groupby('STD_CLSS_NM').AMT.sum(), df_20.groupby('STD_CLSS_NM').AMT.sum()], axis=1, keys=['1903_AMT','2003_AMT']).reset_index()
    diff = diff.fillna(0)
    diff['diff'] = (diff['1903_AMT']-diff['2003_AMT'])/diff['1903_AMT']
    diff['diff'] = diff['diff'].apply(lambda x: 0 if x == -inf else x)
    diff.columns = ['STD_CLSS_NM', '1903_AMT', '2003_AMT', 'diff']
    diff = diff.sort_values(by='diff', ascending=False).reset_index(drop=True)
    return diff

# %%
for sido in sido_list:
  tmp = sido_diff(sido)
  
  globals()['diff_0304_{}'.format(sido)] = tmp

# %%
tmp03 = data_2003.groupby(['CARD_SIDO_NM', 'STD_CLSS_NM']).AMT.sum().reset_index()
tmp04 = data_2004.groupby(['CARD_SIDO_NM', 'STD_CLSS_NM']).AMT.sum().reset_index()
tmp = pd.merge(tmp03, tmp04, on = ['CARD_SIDO_NM', 'STD_CLSS_NM'])
tmp.columns = ['CARD_SIDO_NM', 'STD_CLSS_NM', 'AMT_03', 'AMT_04']
tmp
# Out:
#     CARD_SIDO_NM            STD_CLSS_NM       AMT_03       AMT_04
# 0             강원             건강보조식품 소매업     96059012     88823988
# 1             강원                골프장 운영업   2915797995   4708346820
# 2             강원            과실 및 채소 소매업    994816943   1121028924
# 3             강원      관광 민예품 및 선물용품 소매업     13317300     14360780
# 4             강원        그외 기타 스포츠시설 운영업      2075000       227200
# ..           ...                    ...          ...          ...
# 599           충북  피자 햄버거 샌드위치 및 유사 음식점업   1315245299   1373635928
# 600           충북                한식 음식점업  16152482704  18911036160
# 601           충북                    호텔업     15248550     14121500
# 602           충북          화장품 및 방향제 소매업    428881434    450507431
# 603           충북               휴양콘도 운영업     12733490      9328420
#
# [604 rows x 4 columns]

# %%
tmp['num'] = tmp.apply(lambda x: 1 if x['AMT_03'] < x['AMT_04'] else 0, axis = 1)
tmp
# Out:
#     CARD_SIDO_NM            STD_CLSS_NM       AMT_03       AMT_04  num
# 0             강원             건강보조식품 소매업     96059012     88823988    0
# 1             강원                골프장 운영업   2915797995   4708346820    1
# 2             강원            과실 및 채소 소매업    994816943   1121028924    1
# 3             강원      관광 민예품 및 선물용품 소매업     13317300     14360780    1
# 4             강원        그외 기타 스포츠시설 운영업      2075000       227200    0
# ..           ...                    ...          ...          ...  ...
# 599           충북  피자 햄버거 샌드위치 및 유사 음식점업   1315245299   1373635928    1
# 600           충북                한식 음식점업  16152482704  18911036160    1
# 601           충북                    호텔업     15248550     14121500    0
# 602           충북          화장품 및 방향제 소매업    428881434    450507431    1
# 603           충북               휴양콘도 운영업     12733490      9328420    0
#
# [604 rows x 5 columns]

# %%
tmp[tmp['num'].isnull()]
# Out:
# Empty DataFrame
# Columns: [CARD_SIDO_NM, STD_CLSS_NM, AMT_03, AMT_04, num]
# Index: []

# %%
data = train.copy()

# %%
data = data.merge(tmp[['CARD_SIDO_NM', 'STD_CLSS_NM', 'num']], how = 'left')

data
# Out:
#           REG_YYMM CARD_SIDO_NM CARD_CCG_NM  ...      AMT CNT  num
# 0           201901           강원         강릉시  ...   311200   4  0.0
# 1           201901           강원         강릉시  ...  1374500   8  0.0
# 2           201901           강원         강릉시  ...   818700   6  0.0
# 3           201901           강원         강릉시  ...  1717000   5  0.0
# 4           201901           강원         강릉시  ...  1047300   3  0.0
# ...            ...          ...         ...  ...      ...  ..  ...
# 24697787    202003           충북         충주시  ...    43300   4  0.0
# 24697788    202003           충북         충주시  ...    35000   3  0.0
# 24697789    202003           충북         충주시  ...   188000   6  0.0
# 24697790    202003           충북         충주시  ...    99000   6  0.0
# 24697791    202003           충북         충주시  ...   194000   3  0.0
#
# [24697792 rows x 13 columns]

# %%
data = data.fillna(0)

# %%
data['num'] = data['num'].apply(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24697792 entries, 0 to 24697791
# Data columns (total 13 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   REG_YYMM      int64
#  1   CARD_SIDO_NM  object
#  2   CARD_CCG_NM   object
#  3   STD_CLSS_NM   object
#  4   HOM_SIDO_NM   object
#  5   HOM_CCG_NM    object
#  6   AGE           object
#  7   SEX_CTGO_CD   int64
#  8   FLC           int64
#  9   CSTMR_CNT     int64
#  10  AMT           int64
#  11  CNT           int64
#  12  num           int64
# dtypes: int64(7), object(6)
# memory usage: 2.6+ GB

# %%
for sido in sido_list:
  temp = sampling(sido).reset_index(drop=True)

  temp = data_pre(temp)
  temp = temp.drop(['CARD_CCG_NM', 'HOM_CCG_NM'], axis=1)

  temp_num = encoding(temp)
  temp_data = split(temp_num)

  temp = Model(temp_data, temp_num)

  temp.get_model()

  temp_temp = temp.make_temp()

  temp_sub = temp.make_sub(temp_temp)

  globals()['sub_{}'.format(sido)] = temp_sub
# Out:
# [18:08:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:08:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:08:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:08:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:08:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:08:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:08:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:08:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:08:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:08:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:08:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.259
# [18:08:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:08:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:08:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:08:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:08:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:08:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:08:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:08:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:09:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:09:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:09:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.259
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.258
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.258
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.350
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.350
# --final RSMLE--
# Test Data RMSLE: 1.273
# [18:11:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:11:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:11:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:11:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:11:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:11:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:11:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:11:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:11:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:11:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:11:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.509
# [18:11:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:11:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:11:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:11:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:11:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:11:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:11:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:12:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:12:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:12:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:12:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.509
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.514
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.514
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.602
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.602
# --final RSMLE--
# Test Data RMSLE: 1.520
# [18:14:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.453
# [18:14:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:14:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:15:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:15:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:15:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:15:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:15:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.453
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.454
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.454
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.556
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.556
# --final RSMLE--
# Test Data RMSLE: 1.469
# [18:17:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:17:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:17:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:17:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:17:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:17:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:17:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:17:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:17:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:17:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:17:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.365
# [18:17:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:17:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:17:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:17:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:17:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:18:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:18:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:18:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:18:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:18:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:18:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.365
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.365
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.365
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.467
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.467
# --final RSMLE--
# Test Data RMSLE: 1.381
# [18:20:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:20:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:20:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:20:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:20:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:20:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:20:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:20:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:20:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:20:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:20:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 1.171
# [18:20:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:20:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:21:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:21:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:21:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:21:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:21:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:21:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:21:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:21:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:21:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 1.171
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 1.173
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 1.173
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.236
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.236
# --final RSMLE--
# Test Data RMSLE: 1.174
# [18:23:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:23:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.312
# [18:24:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.312
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.313
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.313
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.385
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.385
# --final RSMLE--
# Test Data RMSLE: 1.314
# [18:26:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:26:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:26:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:26:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:26:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.139
# [18:27:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:27:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.139
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.144
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.144
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.190
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.190
# --final RSMLE--
# Test Data RMSLE: 1.134
# [18:29:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:29:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:29:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:29:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.346
# [18:30:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:30:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.346
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.347
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.347
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.440
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.440
# --final RSMLE--
# Test Data RMSLE: 1.359
# [18:32:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.463
# [18:33:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.463
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.468
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.468
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.553
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.553
# --final RSMLE--
# Test Data RMSLE: 1.471
# [18:36:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 0.982
# [18:36:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:36:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:37:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 0.982
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 0.983
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 0.983
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.012
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.012
# --final RSMLE--
# Test Data RMSLE: 0.970
# [18:39:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:39:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:39:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:39:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:39:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:39:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:39:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:39:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:39:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:39:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:39:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.273
# [18:39:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:39:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:39:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:39:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:39:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:40:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:40:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:40:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:40:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:40:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:40:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.273
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.276
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.276
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.371
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.371
# --final RSMLE--
# Test Data RMSLE: 1.288
# [18:42:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:42:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:42:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:42:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:42:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:42:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:42:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:42:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:42:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:42:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:42:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.250
# [18:42:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:42:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:42:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:42:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:43:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:43:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:43:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:43:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:43:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:43:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:43:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.250
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.247
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.247
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.346
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.346
# --final RSMLE--
# Test Data RMSLE: 1.264
# [18:45:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:45:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:45:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:45:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:45:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:45:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:45:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:45:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:45:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:45:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:45:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.358
# [18:46:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:46:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:46:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:46:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:46:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:46:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:46:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:46:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:46:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:46:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:46:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.358
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.359
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.359
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.458
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.458
# --final RSMLE--
# Test Data RMSLE: 1.377
# [18:48:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:48:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:48:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:48:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:48:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:48:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:48:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:48:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:48:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:48:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:49:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.335
# [18:49:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:49:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:49:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:49:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:49:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:49:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:49:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:49:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:49:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:49:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:49:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.335
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.336
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.336
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.429
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.429
# --final RSMLE--
# Test Data RMSLE: 1.352
# [18:51:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:51:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:51:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:51:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:51:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:51:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:51:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:51:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:51:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:52:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:52:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 0.991
# [18:52:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:52:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:52:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:52:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:52:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:52:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:52:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:52:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:52:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:52:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:52:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 0.991
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 0.995
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 0.995
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.045
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.045
# --final RSMLE--
# Test Data RMSLE: 0.993
# [18:54:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:54:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:54:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:54:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:54:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:54:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:54:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:54:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:55:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:55:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:55:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.372
# [18:55:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:55:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:55:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:55:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:55:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:55:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:55:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:55:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:55:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:55:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:55:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.372
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.372
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.372
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.466
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.466
# --final RSMLE--
# Test Data RMSLE: 1.388
# [18:57:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:57:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:57:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:57:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:57:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:57:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:57:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:58:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:58:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:58:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:58:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.307
# [18:58:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:58:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:58:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:58:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:58:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:58:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:58:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:58:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:58:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:58:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:58:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.307
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.308
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.308
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.401
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.401
# --final RSMLE--
# Test Data RMSLE: 1.322

# %%
def sido_diff(sido):
  df = train[train['CARD_SIDO_NM'] == sido]
  df_19 = df[df['REG_YYMM'] == 201903]
  df_20 = df[df['REG_YYMM'] == 202003]
  diff = pd.concat([df_19.groupby('STD_CLSS_NM').AMT.sum(), df_20.groupby('STD_CLSS_NM').AMT.sum()], axis=1, keys = ['1903_AMT', '2003_AMT']).reset_index()
  diff = diff.fillna(0)
  diff['diff'] = (diff['1903_AMT']-diff['2003_AMT'])/diff['1903_AMT']
  diff.columns = ['STD_CLSS_NM', '1903_AMT', '2003_AMT', 'diff']
  diff = diff[['STD_CLSS_NM', 'diff']]
  diff = diff.sort_values(by='diff', ascending=False).reset_index(drop=True)

  return diff

# %%
for sido in sido_list:
  tmp = sido_diff(sido)

  globals()['diff_{}'.format(sido)] = tmp

# %%
# 시도별 예측 데이터프레임 하나로 병합
test_subs = [sub_강원, sub_경기, sub_경남, sub_경북, sub_광주, sub_대구, sub_대전, sub_부산, sub_서울, sub_세종, sub_울산, sub_인천, sub_전남, sub_전북, sub_제주, sub_충남, sub_충북]
test_diffs = [diff_강원, diff_경기, diff_경남, diff_경북, diff_광주, diff_대구, diff_대전, diff_부산, diff_서울, diff_세종, diff_울산, diff_인천, diff_전남, diff_전북, diff_제주, diff_충남, diff_충북]

# %%
subs = test_subs.copy()
diffs = test_diffs.copy()

# %%
# 샘플로 예측한 값에서 증감율 고려해 수정
for i in range(len(sido_list)):
  subs[i] = subs[i].merge(diffs[i][['STD_CLSS_NM','diff']], how='left', on='STD_CLSS_NM')
  subs[i]['AMT'] = subs[i]['AMT']*(1-subs[i]['diff'])
  subs[i] = subs[i][['REG_YYMM','CARD_SIDO_NM','STD_CLSS_NM','AMT']]

# %%
# 모든 시도 데이터 합치기
test = pd.concat(subs)
test = test.sort_values(by = ['REG_YYMM', 'CARD_SIDO_NM']).reset_index(drop = True)
test
# Out:
#       REG_YYMM CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0       202004           강원             건강보조식품 소매업  2.285799e+08
# 1       202004           강원                골프장 운영업  5.826093e+08
# 2       202004           강원            과실 및 채소 소매업  2.382150e+08
# 3       202004           강원      관광 민예품 및 선물용품 소매업  8.056913e+07
# 4       202004           강원        그외 기타 스포츠시설 운영업  4.543825e+07
# ...        ...          ...                    ...           ...
# 1223    202007           충북  피자 햄버거 샌드위치 및 유사 음식점업  1.331021e+08
# 1224    202007           충북                한식 음식점업  2.770203e+08
# 1225    202007           충북                    호텔업  4.190603e+07
# 1226    202007           충북          화장품 및 방향제 소매업  1.051379e+08
# 1227    202007           충북               휴양콘도 운영업  2.897199e+07
#
# [1228 rows x 4 columns]

# %%
# 제출 파일을 위한 submission 파일 불러오기
project_id = 'jeju-bigquery-282708'
client = bigquery.Client(project = 'jeju-bigquery-282708')

submission = client.query('''
  SELECT 
    * 
  FROM `jeju-bigquery-282708.jeju_bigdata.submission` 
  ''').to_dataframe()

# %%
# 제출파일 양식에 맞게 가공
final = submission.drop(['AMT'], axis=1)
final = final.merge(test, on=['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM'], how='left')
final
# Out:
#         id  REG_YYMM CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0        0    202004           강원             건강보조식품 소매업  2.285799e+08
# 1        1    202004           강원                골프장 운영업  5.826093e+08
# 2        2    202004           강원            과실 및 채소 소매업  2.382150e+08
# 3        3    202004           강원      관광 민예품 및 선물용품 소매업  8.056913e+07
# 4        4    202004           강원   그외 기타 분류안된 오락관련 서비스업           NaN
# ...    ...       ...          ...                    ...           ...
# 1389  1389    202007           충북  피자 햄버거 샌드위치 및 유사 음식점업  1.331021e+08
# 1390  1390    202007           충북                한식 음식점업  2.770203e+08
# 1391  1391    202007           충북                    호텔업  4.190603e+07
# 1392  1392    202007           충북          화장품 및 방향제 소매업  1.051379e+08
# 1393  1393    202007           충북               휴양콘도 운영업  2.897199e+07
#
# [1394 rows x 5 columns]

# %%
final_nan = final[final['AMT'].isnull()].reset_index(drop=True)
final_nan
# Out:
#        id  REG_YYMM CARD_SIDO_NM           STD_CLSS_NM  AMT
# 0       4    202004           강원  그외 기타 분류안된 오락관련 서비스업  NaN
# 1      14    202004           강원                   면세점  NaN
# 2      28    202004           강원               자동차 임대업  NaN
# 3      30    202004           강원             정기 항공 운송업  NaN
# 4      35    202004           강원                택시 운송업  NaN
# ..    ...       ...          ...                   ...  ...
# 165  1357    202007           충북  그외 기타 분류안된 오락관련 서비스업  NaN
# 166  1368    202007           충북                버스 운송업  NaN
# 167  1376    202007           충북                  여행사업  NaN
# 168  1381    202007           충북               자동차 임대업  NaN
# 169  1383    202007           충북             정기 항공 운송업  NaN
#
# [170 rows x 5 columns]

# %%
final_inf = final[final['AMT'] == inf].reset_index(drop = True)
final_inf
# Out:
#      id  REG_YYMM CARD_SIDO_NM           STD_CLSS_NM  AMT
# 0   578    202004           제주  그외 기타 분류안된 오락관련 서비스업  inf
# 1   630    202004           충남                버스 운송업  inf
# 2  1275    202007           제주  그외 기타 분류안된 오락관련 서비스업  inf
# 3  1327    202007           충남                버스 운송업  inf

# %%
train_03 = train[train['REG_YYMM']==202003]
train_03.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1260508 entries, 23437284 to 24697791
# Data columns (total 12 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   REG_YYMM      1260508 non-null  int64
#  1   CARD_SIDO_NM  1260508 non-null  object
#  2   CARD_CCG_NM   1255817 non-null  object
#  3   STD_CLSS_NM   1260508 non-null  object
#  4   HOM_SIDO_NM   1260508 non-null  object
#  5   HOM_CCG_NM    1253658 non-null  object
#  6   AGE           1260508 non-null  object
#  7   SEX_CTGO_CD   1260508 non-null  int64
#  8   FLC           1260508 non-null  int64
#  9   CSTMR_CNT     1260508 non-null  int64
#  10  AMT           1260508 non-null  int64
#  11  CNT           1260508 non-null  int64
# dtypes: int64(6), object(6)
# memory usage: 125.0+ MB

# %%
amt_nan = []
for idx, x in final_nan.iterrows():
  amt = sum(train_03[(train_03['CARD_SIDO_NM']==x['CARD_SIDO_NM']) & (train_03['STD_CLSS_NM']==x['STD_CLSS_NM'])]['AMT'])
  amt_nan.append(amt)

# %%
amt_inf = []
for idx, x in final_inf.iterrows():
  amt = sum(train_03[(train_03['CARD_SIDO_NM']==x['CARD_SIDO_NM']) & (train_03['STD_CLSS_NM']==x['STD_CLSS_NM'])]['AMT'])
  amt_inf.append(amt)

# %%
amt_nan = pd.Series(amt_nan)
final_nan['AMT'] = amt_nan

# %%
amt_inf = pd.Series(amt_inf)
final_inf['AMT'] = amt_inf

# %%
final_nan
# Out:
#        id  REG_YYMM CARD_SIDO_NM           STD_CLSS_NM      AMT
# 0       4    202004           강원  그외 기타 분류안된 오락관련 서비스업        0
# 1      14    202004           강원                   면세점        0
# 2      28    202004           강원               자동차 임대업  4607000
# 3      30    202004           강원             정기 항공 운송업        0
# 4      35    202004           강원                택시 운송업        0
# ..    ...       ...          ...                   ...      ...
# 165  1357    202007           충북  그외 기타 분류안된 오락관련 서비스업        0
# 166  1368    202007           충북                버스 운송업        0
# 167  1376    202007           충북                  여행사업        0
# 168  1381    202007           충북               자동차 임대업        0
# 169  1383    202007           충북             정기 항공 운송업        0
#
# [170 rows x 5 columns]

# %%
final_inf
# Out:
#      id  REG_YYMM CARD_SIDO_NM           STD_CLSS_NM     AMT
# 0   578    202004           제주  그외 기타 분류안된 오락관련 서비스업  313500
# 1   630    202004           충남                버스 운송업  322074
# 2  1275    202007           제주  그외 기타 분류안된 오락관련 서비스업  313500
# 3  1327    202007           충남                버스 운송업  322074

# %%
final_nan[final_nan['AMT'] != 0]
# Out:
#        id  REG_YYMM CARD_SIDO_NM           STD_CLSS_NM      AMT
# 2      28    202004           강원               자동차 임대업  4607000
# 6      53    202004           경기             내항 여객 운송업   261500
# 9      86    202004           경남  그외 기타 분류안된 오락관련 서비스업   482700
# 14    146    202004           경북                  여행사업   171000
# 15    151    202004           경북               자동차 임대업   778000
# 28    254    202004           대전          기타 수상오락 서비스업    94000
# 33    274    202004           대전               자동차 임대업  1276500
# 38    315    202004           부산               자동차 임대업   773000
# 61    474    202004           인천                  여행사업  1580000
# 62    479    202004           인천               자동차 임대업   536100
# 71    561    202004           전북               자동차 임대업  1261000
# 72    582    202004           제주          기타 수상오락 서비스업  1606700
# 74    609    202004           제주                택시 운송업   471100
# 75    619    202004           충남  그외 기타 분류안된 오락관련 서비스업   784000
# 78    643    202004           충남               자동차 임대업   282000
# 87    725    202007           강원               자동차 임대업  4607000
# 91    750    202007           경기             내항 여객 운송업   261500
# 94    783    202007           경남  그외 기타 분류안된 오락관련 서비스업   482700
# 99    843    202007           경북                  여행사업   171000
# 100   848    202007           경북               자동차 임대업   778000
# 113   951    202007           대전          기타 수상오락 서비스업    94000
# 118   971    202007           대전               자동차 임대업  1276500
# 123  1012    202007           부산               자동차 임대업   773000
# 146  1171    202007           인천                  여행사업  1580000
# 147  1176    202007           인천               자동차 임대업   536100
# 156  1258    202007           전북               자동차 임대업  1261000
# 157  1279    202007           제주          기타 수상오락 서비스업  1606700
# 159  1306    202007           제주                택시 운송업   471100
# 160  1316    202007           충남  그외 기타 분류안된 오락관련 서비스업   784000
# 163  1340    202007           충남               자동차 임대업   282000

# %%
final = final.dropna(subset=['AMT'])
final
# Out:
#         id  REG_YYMM CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0        0    202004           강원             건강보조식품 소매업  2.285799e+08
# 1        1    202004           강원                골프장 운영업  5.826093e+08
# 2        2    202004           강원            과실 및 채소 소매업  2.382150e+08
# 3        3    202004           강원      관광 민예품 및 선물용품 소매업  8.056913e+07
# 5        5    202004           강원        그외 기타 스포츠시설 운영업  4.543825e+07
# ...    ...       ...          ...                    ...           ...
# 1389  1389    202007           충북  피자 햄버거 샌드위치 및 유사 음식점업  1.331021e+08
# 1390  1390    202007           충북                한식 음식점업  2.770203e+08
# 1391  1391    202007           충북                    호텔업  4.190603e+07
# 1392  1392    202007           충북          화장품 및 방향제 소매업  1.051379e+08
# 1393  1393    202007           충북               휴양콘도 운영업  2.897199e+07
#
# [1224 rows x 5 columns]

# %%
final = pd.concat([final, final_nan])
final = final.sort_values('id').reset_index(drop=True)

# %%
final = final.replace([np.inf, -np.inf], np.nan).dropna(subset = ['AMT'])

# %%
final = pd.concat([final, final_inf])
final = final.sort_values('id').reset_index(drop = True)

# %%
final
# Out:
#         id  REG_YYMM CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0        0    202004           강원             건강보조식품 소매업  2.285799e+08
# 1        1    202004           강원                골프장 운영업  5.826093e+08
# 2        2    202004           강원            과실 및 채소 소매업  2.382150e+08
# 3        3    202004           강원      관광 민예품 및 선물용품 소매업  8.056913e+07
# 4        4    202004           강원   그외 기타 분류안된 오락관련 서비스업  0.000000e+00
# ...    ...       ...          ...                    ...           ...
# 1389  1389    202007           충북  피자 햄버거 샌드위치 및 유사 음식점업  1.331021e+08
# 1390  1390    202007           충북                한식 음식점업  2.770203e+08
# 1391  1391    202007           충북                    호텔업  4.190603e+07
# 1392  1392    202007           충북          화장품 및 방향제 소매업  1.051379e+08
# 1393  1393    202007           충북               휴양콘도 운영업  2.897199e+07
#
# [1394 rows x 5 columns]

# %%
final[final['AMT'] == inf]
# Out:
# Empty DataFrame
# Columns: [id, REG_YYMM, CARD_SIDO_NM, STD_CLSS_NM, AMT]
# Index: []

# %%
final['AMT'] = final['AMT'].astype(int)
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1394 entries, 0 to 1393
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1394 non-null   int64
#  1   REG_YYMM      1394 non-null   int64
#  2   CARD_SIDO_NM  1394 non-null   object
#  3   STD_CLSS_NM   1394 non-null   object
#  4   AMT           1394 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 54.6+ KB

# %%
final.to_csv('/content/drive/My Drive/Colab Notebooks/jeju/submission_0729.csv', encoding='utf-8-sig', index=False)
