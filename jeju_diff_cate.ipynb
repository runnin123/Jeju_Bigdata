# %% [markdown]
# <a href="https://colab.research.google.com/github/runnin123/Jeju_Bigdata/blob/master/jeju_diff_cate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from google.cloud import bigquery
from tabulate import tabulate
import pandas as pd
import numpy as np
import sklearn
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from itertools import product

# 평가 메트릭
from sklearn.metrics import mean_squared_error, mean_absolute_error

# 통계
from scipy import stats
from scipy.stats import norm, skew #for some statistics

from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error

# %%
class Model:
    # Initialization method of the Model class about definition of the data
    # Input : split_data(Training/Test set of the independent value and the dependent value)
    #       : num(encoding_data)
    # Definition of the X
    def __init__(self, split_data, num):
        self.X_train = split_data[0]
        self.X_test = split_data[1]
        self.y_train = split_data[2]
        self.y_test = split_data[3]
        self.encoding_data = num

    # the rmsle between the actual value and predicted value
    def rmsle(self, y, pred): 
        log_y = np.log1p(y)
        log_pred = np.log1p(pred)
        squared_error = (log_y - log_pred)**2
        rmsle = np.sqrt(np.mean(squared_error))
        print('Test Data RMSLE: {0:.3f}'.format(rmsle))
        return round(rmsle, 3)

    # get best estimator and rmsle through GridSearchCV
    def best_params_model(self, model, params):
        cv_model = GridSearchCV(model, param_grid=params, scoring="neg_mean_squared_error", cv = 5)
        cv_model.fit(self.X_train, self.y_train)
        print("----", model.__class__.__name__, "----")
        print("GridSearchCV 최적 하이퍼 파라미터 :", cv_model.best_params_)

        eval_pred = cv_model.predict(self.X_test)
        eval_pred = np.expm1(eval_pred)
        rmsle_ = self.rmsle(self.y_test, eval_pred)

        return  cv_model.best_estimator_, rmsle_

    # Process about finding the ratio of XGB and GBM and LGB
    def get_model(self):
        xgb = XGBRegressor(random_state=0)
        gbm = GradientBoostingRegressor(random_state=0)
        lgb = LGBMRegressor(random_state=0)

        params = {'n_estimators': [1000, 2000]}

        models = [xgb, gbm, lgb]
        best_models = []
        rmsles = []
        
        for model in models:
            new_model = self.best_params_model(model, params)[0]
            new_rmsle = self.best_params_model(model, params)[1]
            best_models.append(new_model)
            rmsles.append(new_rmsle)

        self.xgb_reg = best_models[0]
        self.gbm_reg = best_models[1]
        self.lgb_reg = best_models[2]

        self.xgb_rmsle = rmsles[0]
        self.gbm_rmsle = rmsles[1]
        self.lgb_rmsle = rmsles[2]

        xgb_pred = self.xgb_reg.predict(self.X_test)
        xgb_pred = np.expm1(xgb_pred)

        gbm_pred = self.gbm_reg.predict(self.X_test)
        gbm_pred = np.expm1(gbm_pred)

        lgb_pred = self.lgb_reg.predict(self.X_test)
        lgb_pred = np.expm1(lgb_pred)

        pred = np.array([xgb_pred, gbm_pred, lgb_pred])
        pred = np.transpose(pred)

        rmsle_sum = self.xgb_rmsle + self.gbm_rmsle + self.lgb_rmsle

        self.xgb_per = self.xgb_rmsle / rmsle_sum
        self.gbm_per = self.gbm_rmsle / rmsle_sum
        self.lgb_per = self.lgb_rmsle / rmsle_sum
        
        final = xgb_pred*self.xgb_per + gbm_pred*self.gbm_per + lgb_pred*self.lgb_per
        print("--final RSMLE--")
        self.rmsle(self.y_test, final)

    # making the prediction template about 03/04/07/2020
    def make_temp(self):
        CARD_SIDO_NMs = self.encoding_data['CARD_SIDO_NM'].unique()
        STD_CLSS_NMs  = self.encoding_data['STD_CLSS_NM'].unique()
        HOM_SIDO_NMs  = self.encoding_data['HOM_SIDO_NM'].unique()
        AGEs          = self.encoding_data['AGE'].unique()
        SEX_CTGO_CDs  = self.encoding_data['SEX_CTGO_CD'].unique()
        FLCs          = self.encoding_data['FLC'].unique()
        nums          = self.encoding_data['num'].unique()
        # coronas       = self.encoding_data['corona'].unique()
        cates         = self.encoding_data['cate'].unique()
        years         = [2020]
        months        = [4, 7]

        comb_list = [CARD_SIDO_NMs, STD_CLSS_NMs,HOM_SIDO_NMs, AGEs, SEX_CTGO_CDs, FLCs, nums, cates, years, months]
        temp = np.array(list(product(*comb_list)))

        train_features = self.encoding_data.drop(['CSTMR_CNT', 'AMT', 'CNT'], axis=1)
        tmp = pd.DataFrame(data=temp, columns=train_features.columns)

        return tmp

    # making submission
    def make_sub(self, temp):
        xgb_pred = self.xgb_reg.predict(temp)
        xgb_pred = np.expm1(xgb_pred)

        gbm_pred = self.gbm_reg.predict(temp)
        gbm_pred = np.expm1(gbm_pred)

        lgb_pred = self.lgb_reg.predict(temp)
        lgb_pred = np.expm1(lgb_pred)

        final_rmsle = xgb_pred*self.xgb_per + gbm_pred*self.gbm_per + lgb_pred*self.lgb_per

        temp['AMT'] = np.round(final_rmsle, 0)
        temp['REG_YYMM'] = temp['year']*100 + temp['month']
        temp = temp[['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM', 'AMT']]
        temp = temp.groupby(['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM']).sum().reset_index(drop = False)

        temp['CARD_SIDO_NM'] = encoders['CARD_SIDO_NM'].inverse_transform(temp['CARD_SIDO_NM'])
        temp['STD_CLSS_NM'] = encoders['STD_CLSS_NM'].inverse_transform(temp['STD_CLSS_NM'])

        return temp

# %%
def sampling(sido):
    df = data[data['CARD_SIDO_NM']==sido]
    df = df.sample(n=10000)
    return df

# %%
def grap_year(data):
    data = str(data)
    return int(data[:4])

def grap_month(data):
    data = str(data)
    return int(data[4:])

# %%
def grap_cate(data):
  incr = ['골프장 운영업']
  des = ['관광 민예품 및 선물용품 소매업', '그외 기타 스포츠시설 운영업', '마사지업', '면세점', '버스 운송업', '여관업', '욕탕업', '전시 및 행사 대행업', '정기 항공 운송업', '호텔업', '휴양콘도 운영업', '여행사업' '일반유흥 주점업']

  if data in incr:
    return 1
  elif data in des:
    return -1
  else:
    return 0

# %%
def data_pre(data):
    data = data.fillna('')
    data['year'] = data['REG_YYMM'].apply(lambda x: grap_year(x))
    data['month'] = data['REG_YYMM'].apply(lambda x: grap_month(x))
    data['cate'] = data['STD_CLSS_NM'].apply(lambda x: grap_cate(x))
    data = data.drop(['REG_YYMM'], axis = 1)

    return data

# %%
def encoding(data):

    global encoders
    dtypes = data.dtypes
    encoders = {}
    for column in data.columns:
        if str(dtypes[column]) == 'object':
            encoder = LabelEncoder()
            encoder.fit(data[column])
            encoders[column] = encoder

    data_num = data.copy()

    for column in encoders.keys():
        encoder = encoders[column]
        data_num[column] = encoder.transform(data[column])

    return data_num

# %%
def split(data_num):
    split_data = []

    X_data, y_data = data_num.loc[:, data_num.columns != 'AMT'], data_num['AMT']
    X_data = X_data.drop(['CSTMR_CNT', 'CNT'], axis=1)
    X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, random_state=126, shuffle=True)
    y_train = np.log1p(y_train)
    
    return X_train, X_test, y_train, y_test

# %%
# train 데이터 불러오기
train = pd.read_csv('/content/drive/My Drive/Colab Notebooks/jeju/201901-202003.csv')
# 시도별 예측 데이터 프레임 생성을 위한 시도 리스트 생성
sido_list = train['CARD_SIDO_NM'].unique().tolist()

# %%
data_2004 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/jeju/202004.csv')

# %%
data_2003 = train[train['REG_YYMM'] == 202003]

# %%
tmp03 = data_2003.groupby(['CARD_SIDO_NM', 'STD_CLSS_NM']).AMT.sum().reset_index()
tmp04 = data_2004.groupby(['CARD_SIDO_NM', 'STD_CLSS_NM']).AMT.sum().reset_index()
tmp = pd.merge(tmp03, tmp04, on = ['CARD_SIDO_NM', 'STD_CLSS_NM'])
tmp.columns = ['CARD_SIDO_NM', 'STD_CLSS_NM', 'AMT_03', 'AMT_04']
tmp
# Out:
#     CARD_SIDO_NM            STD_CLSS_NM       AMT_03       AMT_04
# 0             강원             건강보조식품 소매업     96059012     88823988
# 1             강원                골프장 운영업   2915797995   4708346820
# 2             강원            과실 및 채소 소매업    994816943   1121028924
# 3             강원      관광 민예품 및 선물용품 소매업     13317300     14360780
# 4             강원        그외 기타 스포츠시설 운영업      2075000       227200
# ..           ...                    ...          ...          ...
# 599           충북  피자 햄버거 샌드위치 및 유사 음식점업   1315245299   1373635928
# 600           충북                한식 음식점업  16152482704  18911036160
# 601           충북                    호텔업     15248550     14121500
# 602           충북          화장품 및 방향제 소매업    428881434    450507431
# 603           충북               휴양콘도 운영업     12733490      9328420
#
# [604 rows x 4 columns]

# %%
tmp['num'] = tmp.apply(lambda x: 1 if x['AMT_03'] < x['AMT_04'] else 0, axis = 1)
tmp
# Out:
#     CARD_SIDO_NM            STD_CLSS_NM       AMT_03       AMT_04  num
# 0             강원             건강보조식품 소매업     96059012     88823988    0
# 1             강원                골프장 운영업   2915797995   4708346820    1
# 2             강원            과실 및 채소 소매업    994816943   1121028924    1
# 3             강원      관광 민예품 및 선물용품 소매업     13317300     14360780    1
# 4             강원        그외 기타 스포츠시설 운영업      2075000       227200    0
# ..           ...                    ...          ...          ...  ...
# 599           충북  피자 햄버거 샌드위치 및 유사 음식점업   1315245299   1373635928    1
# 600           충북                한식 음식점업  16152482704  18911036160    1
# 601           충북                    호텔업     15248550     14121500    0
# 602           충북          화장품 및 방향제 소매업    428881434    450507431    1
# 603           충북               휴양콘도 운영업     12733490      9328420    0
#
# [604 rows x 5 columns]

# %%
data = train.copy()

# %%
data = data.merge(tmp[['CARD_SIDO_NM', 'STD_CLSS_NM', 'num']], how = 'left')

data
# Out:
#           REG_YYMM CARD_SIDO_NM CARD_CCG_NM  ...      AMT CNT  num
# 0           201901           강원         강릉시  ...   311200   4  0.0
# 1           201901           강원         강릉시  ...  1374500   8  0.0
# 2           201901           강원         강릉시  ...   818700   6  0.0
# 3           201901           강원         강릉시  ...  1717000   5  0.0
# 4           201901           강원         강릉시  ...  1047300   3  0.0
# ...            ...          ...         ...  ...      ...  ..  ...
# 24697787    202003           충북         충주시  ...    43300   4  0.0
# 24697788    202003           충북         충주시  ...    35000   3  0.0
# 24697789    202003           충북         충주시  ...   188000   6  0.0
# 24697790    202003           충북         충주시  ...    99000   6  0.0
# 24697791    202003           충북         충주시  ...   194000   3  0.0
#
# [24697792 rows x 13 columns]

# %%
data = data.fillna(0)
data['num'] = data['num'].apply(int)

# %%
for sido in sido_list:
  temp = sampling(sido).reset_index(drop=True)

  temp = data_pre(temp)
  temp = temp.drop(['CARD_CCG_NM', 'HOM_CCG_NM'], axis=1)

  temp_num = encoding(temp)
  temp_data = split(temp_num)

  temp = Model(temp_data, temp_num)

  temp.get_model()

  temp_temp = temp.make_temp()

  temp_sub = temp.make_sub(temp_temp)

  globals()['sub_{}'.format(sido)] = temp_sub
# Out:
# [09:40:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:40:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:40:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:40:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:40:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:40:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:40:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:41:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:41:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:41:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:41:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.220
# [09:41:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:41:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:41:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:41:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:41:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:41:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:41:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:41:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:41:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:41:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:42:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.220
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.221
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.221
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.295
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.295
# --final RSMLE--
# Test Data RMSLE: 1.231
# [09:45:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:45:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:45:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:45:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:45:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:45:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:45:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:45:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:46:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:46:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:46:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.492
# [09:46:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:46:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:46:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:46:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:46:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:46:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:46:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:46:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:46:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:46:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:46:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.492
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.493
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.493
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.607
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.607
# --final RSMLE--
# Test Data RMSLE: 1.517
# [09:50:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:50:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:50:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:50:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:50:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:50:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:50:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:50:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:51:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:51:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:51:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.498
# [09:51:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:51:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:51:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:51:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:51:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:51:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:51:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:51:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:51:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:51:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:51:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.498
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.499
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.499
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.600
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.600
# --final RSMLE--
# Test Data RMSLE: 1.517
# [09:55:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:55:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:55:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:55:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:55:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:55:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:55:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:55:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:56:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:56:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:56:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.372
# [09:56:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:56:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:56:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:56:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:56:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:56:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:56:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:56:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:56:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:56:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:56:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.372
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.374
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.374
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.438
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.438
# --final RSMLE--
# Test Data RMSLE: 1.375
# [10:00:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:00:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:00:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:00:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:00:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:00:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:00:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:00:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:00:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:01:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:01:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 1.165
# [10:01:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:01:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:01:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:01:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:01:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:01:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:01:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:01:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:01:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:01:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:01:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 1.165
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 1.174
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 1.174
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.210
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.210
# --final RSMLE--
# Test Data RMSLE: 1.162
# [10:05:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:06:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:06:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:06:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:06:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:06:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:06:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:06:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:06:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:06:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:06:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.297
# [10:06:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:06:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:06:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:06:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:06:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:06:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:07:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:07:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:07:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:07:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:07:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.297
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.296
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.296
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.348
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.348
# --final RSMLE--
# Test Data RMSLE: 1.293
# [10:10:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:10:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:10:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:11:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:11:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:11:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:11:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:11:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:11:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:11:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:11:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 1.130
# [10:11:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:11:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:11:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:11:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:11:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:11:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:11:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:12:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:12:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:12:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:12:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 1.130
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 1.126
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 1.126
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.173
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.173
# --final RSMLE--
# Test Data RMSLE: 1.125
# [10:16:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:16:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:16:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:16:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:16:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:16:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:16:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:16:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:16:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:16:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:17:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.311
# [10:17:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:17:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:17:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:17:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:17:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:17:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:17:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:17:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:17:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:17:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:17:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.311
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.317
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.317
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.373
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.373
# --final RSMLE--
# Test Data RMSLE: 1.311
# [10:21:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:21:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:21:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:21:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:21:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:21:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:21:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:21:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:21:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:22:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:22:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.449
# [10:22:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:22:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:22:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:22:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:22:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:22:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:22:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:22:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:22:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:22:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:22:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.449
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.452
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.452
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.547
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.547
# --final RSMLE--
# Test Data RMSLE: 1.461
# [10:26:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 0.975
# [10:27:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 0.975
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 0.976
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 0.976
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 0.993
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 0.993
# --final RSMLE--
# Test Data RMSLE: 0.961
# [10:31:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:31:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:31:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:31:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:32:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:32:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:32:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:32:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:32:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:32:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:32:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.245
# [10:32:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:32:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:32:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:32:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:32:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:32:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:32:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:32:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:33:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:33:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:33:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.245
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.244
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.244
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.306
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.306
# --final RSMLE--
# Test Data RMSLE: 1.244
# [10:36:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:36:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:36:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:36:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:36:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:37:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:37:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:37:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:37:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:37:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:37:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.214
# [10:37:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:37:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:37:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:37:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:37:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:37:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:37:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:37:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:38:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:38:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:38:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.214
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.215
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.215
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.295
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.295
# --final RSMLE--
# Test Data RMSLE: 1.219
# [10:41:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:41:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:41:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:42:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:42:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:42:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:42:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:42:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:42:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:42:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:42:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.406
# [10:42:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:42:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:42:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:42:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:42:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:42:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:42:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:43:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:43:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:43:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:43:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.406
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.407
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.407
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.511
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.511
# --final RSMLE--
# Test Data RMSLE: 1.424
# [10:46:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:46:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:46:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:46:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:47:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:47:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:47:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:47:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:47:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:47:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:47:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.355
# [10:47:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:47:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:47:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:47:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:47:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:47:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:47:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:47:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.355
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.359
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.359
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.472
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.472
# --final RSMLE--
# Test Data RMSLE: 1.379
# [10:51:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 0.989
# [10:52:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:53:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:53:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:53:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 0.989
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 0.990
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 0.990
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.022
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.022
# --final RSMLE--
# Test Data RMSLE: 0.981
# [10:56:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:56:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:56:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:56:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:56:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:57:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:57:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:57:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:57:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:57:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:57:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.288
# [10:57:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:57:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:57:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:57:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:57:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:57:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:57:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:57:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:58:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:58:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:58:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.288
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.292
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.292
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.384
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.384
# --final RSMLE--
# Test Data RMSLE: 1.303
# [11:01:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:01:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:01:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:02:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:02:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:02:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:02:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:02:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:02:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:02:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:02:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.293
# [11:02:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:02:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:02:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:02:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:02:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:02:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:02:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:03:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:03:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:03:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:03:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.293
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.295
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.295
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.374
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.374
# --final RSMLE--
# Test Data RMSLE: 1.304

# %%
from numpy import inf

def sido_diff(sido):


  df = train[train['CARD_SIDO_NM'] == sido]
  df_19 = df[df['REG_YYMM'] == 201903]
  df_20 = df[df['REG_YYMM'] == 202003]
  diff = pd.concat([df_19.groupby('STD_CLSS_NM').AMT.sum(), df_20.groupby('STD_CLSS_NM').AMT.sum()], axis=1, keys = ['1903_AMT', '2003_AMT']).reset_index()
  diff = diff.fillna(0)
  diff['diff'] = (diff['1903_AMT']-diff['2003_AMT'])/diff['1903_AMT']
  diff['diff'] = diff['diff'].apply(lambda x: 0 if x == -inf else x)
  diff.columns = ['STD_CLSS_NM', '1903_AMT', '2003_AMT', 'diff']
  diff = diff[['STD_CLSS_NM', 'diff']]
  diff = diff.sort_values(by='diff', ascending=False).reset_index(drop=True)

  return diff

# %%
for sido in sido_list:
  tmp = sido_diff(sido)

  globals()['diff_{}'.format(sido)] = tmp

# %%
test_subs = [sub_강원, sub_경기, sub_경남, sub_경북, sub_광주, sub_대구, sub_대전, sub_부산, sub_서울, sub_세종, sub_울산, sub_인천, sub_전남, sub_전북, sub_제주, sub_충남, sub_충북]
test_diffs = [diff_강원, diff_경기, diff_경남, diff_경북, diff_광주, diff_대구, diff_대전, diff_부산, diff_서울, diff_세종, diff_울산, diff_인천, diff_전남, diff_전북, diff_제주, diff_충남, diff_충북]

# %%
subs = test_subs.copy()
diffs = test_diffs.copy()

# %%
for i in range(len(sido_list)):
  subs[i] = subs[i].merge(diffs[i][['STD_CLSS_NM','diff']], how='left', on='STD_CLSS_NM')
  subs[i]['AMT'] = subs[i]['AMT']*(1-subs[i]['diff'])
  subs[i] = subs[i][['REG_YYMM','CARD_SIDO_NM','STD_CLSS_NM','AMT']]

# %%
test = pd.concat(subs)
test = test.sort_values(by = ['REG_YYMM', 'CARD_SIDO_NM']).reset_index(drop = True)
test
# Out:
#       REG_YYMM CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0         1920           강원             건강보조식품 소매업  9.647964e+08
# 1         1920           강원                골프장 운영업  1.558428e+09
# 2         1920           강원            과실 및 채소 소매업  1.193421e+09
# 3         1920           강원      관광 민예품 및 선물용품 소매업  6.687905e+08
# 4         1920           강원        그외 기타 스포츠시설 운영업  6.563734e+08
# ...        ...          ...                    ...           ...
# 1825      2120           충북  피자 햄버거 샌드위치 및 유사 음식점업  3.079860e+08
# 1826      2120           충북                한식 음식점업  9.999136e+08
# 1827      2120           충북                    호텔업  2.072207e+08
# 1828      2120           충북          화장품 및 방향제 소매업  3.917083e+08
# 1829      2120           충북               휴양콘도 운영업  1.183461e+08
#
# [1830 rows x 4 columns]

# %%
def date_error(data):
  if data == 1920:
    return 202004
  else :
    return 202007

# %%
test['REG_YYMM'] = test['REG_YYMM'].apply(lambda x: date_error(x))
test
# Out:
#       REG_YYMM CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0       202004           강원             건강보조식품 소매업  9.647964e+08
# 1       202004           강원                골프장 운영업  1.558428e+09
# 2       202004           강원            과실 및 채소 소매업  1.193421e+09
# 3       202004           강원      관광 민예품 및 선물용품 소매업  6.687905e+08
# 4       202004           강원        그외 기타 스포츠시설 운영업  6.563734e+08
# ...        ...          ...                    ...           ...
# 1825    202007           충북  피자 햄버거 샌드위치 및 유사 음식점업  3.079860e+08
# 1826    202007           충북                한식 음식점업  9.999136e+08
# 1827    202007           충북                    호텔업  2.072207e+08
# 1828    202007           충북          화장품 및 방향제 소매업  3.917083e+08
# 1829    202007           충북               휴양콘도 운영업  1.183461e+08
#
# [1830 rows x 4 columns]

# %%
project_id = 'jeju-bigquery-282708'
client = bigquery.Client(project = 'jeju-bigquery-282708')

submission = client.query('''
  SELECT 
    * 
  FROM `jeju-bigquery-282708.jeju_bigdata.submission` 
  ''').to_dataframe()

# %%
final = submission.drop(['AMT'], axis=1)
final = final.merge(test, on=['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM'], how='left')
final
# Out:
#         id  REG_YYMM CARD_SIDO_NM           STD_CLSS_NM           AMT
# 0        0    202004           강원            건강보조식품 소매업  9.647964e+08
# 1        1    202004           강원               골프장 운영업  1.558428e+09
# 2        2    202004           강원           과실 및 채소 소매업  1.193421e+09
# 3        3    202004           강원     관광 민예품 및 선물용품 소매업  6.687905e+08
# 4        4    202004           강원  그외 기타 분류안된 오락관련 서비스업           NaN
# ...    ...       ...          ...                   ...           ...
# 1999  1391    202007           충북                   호텔업  2.072207e+08
# 2000  1392    202007           충북         화장품 및 방향제 소매업  3.917083e+08
# 2001  1392    202007           충북         화장품 및 방향제 소매업  3.917083e+08
# 2002  1393    202007           충북              휴양콘도 운영업  1.183461e+08
# 2003  1393    202007           충북              휴양콘도 운영업  1.183461e+08
#
# [2004 rows x 5 columns]

# %%
final_nan = final[final['AMT'].isnull()].reset_index(drop=True)
final_nan
# Out:
#        id  REG_YYMM CARD_SIDO_NM           STD_CLSS_NM  AMT
# 0       4    202004           강원  그외 기타 분류안된 오락관련 서비스업  NaN
# 1      14    202004           강원                   면세점  NaN
# 2      28    202004           강원               자동차 임대업  NaN
# 3      30    202004           강원             정기 항공 운송업  NaN
# 4      35    202004           강원                택시 운송업  NaN
# ..    ...       ...          ...                   ...  ...
# 178  1357    202007           충북  그외 기타 분류안된 오락관련 서비스업  NaN
# 179  1368    202007           충북                버스 운송업  NaN
# 180  1376    202007           충북                  여행사업  NaN
# 181  1381    202007           충북               자동차 임대업  NaN
# 182  1383    202007           충북             정기 항공 운송업  NaN
#
# [183 rows x 5 columns]

# %%
train_03 = train[train['REG_YYMM']==202003]
train_03.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1260508 entries, 23437284 to 24697791
# Data columns (total 12 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   REG_YYMM      1260508 non-null  int64
#  1   CARD_SIDO_NM  1260508 non-null  object
#  2   CARD_CCG_NM   1255817 non-null  object
#  3   STD_CLSS_NM   1260508 non-null  object
#  4   HOM_SIDO_NM   1260508 non-null  object
#  5   HOM_CCG_NM    1253658 non-null  object
#  6   AGE           1260508 non-null  object
#  7   SEX_CTGO_CD   1260508 non-null  int64
#  8   FLC           1260508 non-null  int64
#  9   CSTMR_CNT     1260508 non-null  int64
#  10  AMT           1260508 non-null  int64
#  11  CNT           1260508 non-null  int64
# dtypes: int64(6), object(6)
# memory usage: 125.0+ MB

# %%
amt_nan = []
for idx, x in final_nan.iterrows():
  amt = sum(train_03[(train_03['CARD_SIDO_NM']==x['CARD_SIDO_NM']) & (train_03['STD_CLSS_NM']==x['STD_CLSS_NM'])]['AMT'])
  amt_nan.append(amt)

# %%
amt_nan = pd.Series(amt_nan)
final_nan['AMT'] = amt_nan

# %%
final_nan
# Out:
#        id  REG_YYMM CARD_SIDO_NM           STD_CLSS_NM      AMT
# 0       4    202004           강원  그외 기타 분류안된 오락관련 서비스업        0
# 1      14    202004           강원                   면세점        0
# 2      28    202004           강원               자동차 임대업  4607000
# 3      30    202004           강원             정기 항공 운송업        0
# 4      35    202004           강원                택시 운송업        0
# ..    ...       ...          ...                   ...      ...
# 178  1357    202007           충북  그외 기타 분류안된 오락관련 서비스업        0
# 179  1368    202007           충북                버스 운송업        0
# 180  1376    202007           충북                  여행사업        0
# 181  1381    202007           충북               자동차 임대업        0
# 182  1383    202007           충북             정기 항공 운송업        0
#
# [183 rows x 5 columns]

# %%
final = final.dropna(subset=['AMT'])
final
# Out:
#         id  REG_YYMM CARD_SIDO_NM        STD_CLSS_NM           AMT
# 0        0    202004           강원         건강보조식품 소매업  9.647964e+08
# 1        1    202004           강원            골프장 운영업  1.558428e+09
# 2        2    202004           강원        과실 및 채소 소매업  1.193421e+09
# 3        3    202004           강원  관광 민예품 및 선물용품 소매업  6.687905e+08
# 5        5    202004           강원    그외 기타 스포츠시설 운영업  6.563734e+08
# ...    ...       ...          ...                ...           ...
# 1999  1391    202007           충북                호텔업  2.072207e+08
# 2000  1392    202007           충북      화장품 및 방향제 소매업  3.917083e+08
# 2001  1392    202007           충북      화장품 및 방향제 소매업  3.917083e+08
# 2002  1393    202007           충북           휴양콘도 운영업  1.183461e+08
# 2003  1393    202007           충북           휴양콘도 운영업  1.183461e+08
#
# [1821 rows x 5 columns]

# %%
final = pd.concat([final, final_nan])
final = final.sort_values('id').reset_index(drop=True)

final
# Out:
#         id  REG_YYMM CARD_SIDO_NM           STD_CLSS_NM           AMT
# 0        0    202004           강원            건강보조식품 소매업  9.647964e+08
# 1        1    202004           강원               골프장 운영업  1.558428e+09
# 2        2    202004           강원           과실 및 채소 소매업  1.193421e+09
# 3        3    202004           강원     관광 민예품 및 선물용품 소매업  6.687905e+08
# 4        4    202004           강원  그외 기타 분류안된 오락관련 서비스업  0.000000e+00
# ...    ...       ...          ...                   ...           ...
# 1999  1391    202007           충북                   호텔업  2.072207e+08
# 2000  1392    202007           충북         화장품 및 방향제 소매업  3.917083e+08
# 2001  1392    202007           충북         화장품 및 방향제 소매업  3.917083e+08
# 2002  1393    202007           충북              휴양콘도 운영업  1.183461e+08
# 2003  1393    202007           충북              휴양콘도 운영업  1.183461e+08
#
# [2004 rows x 5 columns]

# %%
final['AMT'] = final['AMT'].astype(int)
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2004 entries, 0 to 2003
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            2004 non-null   int64
#  1   REG_YYMM      2004 non-null   int64
#  2   CARD_SIDO_NM  2004 non-null   object
#  3   STD_CLSS_NM   2004 non-null   object
#  4   AMT           2004 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 78.4+ KB

# %%
final.to_csv('/content/drive/My Drive/Colab Notebooks/jeju/submission_0730_cate.csv', encoding='utf-8-sig', index=False)
