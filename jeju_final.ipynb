# %% [markdown]
# <a href="https://colab.research.google.com/github/runnin123/Jeju_Bigdata/blob/master/jeju_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from google.cloud import bigquery
from tabulate import tabulate
import pandas as pd
import numpy as np
import sklearn
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from itertools import product

# 평가 메트릭
from sklearn.metrics import mean_squared_error, mean_absolute_error

# 통계
from scipy import stats
from scipy.stats import norm, skew #for some statistics

from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error

# %%
class Model:
    # Initialization method of the Model class about definition of the data
    # Input : split_data(Training/Test set of the independent value and the dependent value)
    #       : num(encoding_data)
    # Definition of the X
    def __init__(self, split_data, num):
        self.X_train = split_data[0]
        self.X_test = split_data[1]
        self.y_train = split_data[2]
        self.y_test = split_data[3]
        self.encoding_data = num

    # the rmsle between the actual value and predicted value
    def rmsle(self, y, pred): 
        log_y = np.log1p(y)
        log_pred = np.log1p(pred)
        squared_error = (log_y - log_pred)**2
        rmsle = np.sqrt(np.mean(squared_error))
        print('Test Data RMSLE: {0:.3f}'.format(rmsle))
        return round(rmsle, 3)

    # get best estimator and rmsle through GridSearchCV
    def best_params_model(self, model, params):
        cv_model = GridSearchCV(model, param_grid=params, scoring="neg_mean_squared_error", cv = 5)
        cv_model.fit(self.X_train, self.y_train)
        print("----", model.__class__.__name__, "----")
        print("GridSearchCV 최적 하이퍼 파라미터 :", cv_model.best_params_)

        eval_pred = cv_model.predict(self.X_test)
        eval_pred = np.expm1(eval_pred)
        rmsle_ = self.rmsle(self.y_test, eval_pred)

        return  cv_model.best_estimator_, rmsle_

    # Process about finding the ratio of XGB and GBM and LGB
    def get_model(self):
        xgb = XGBRegressor(random_state=0)
        gbm = GradientBoostingRegressor(random_state=0)
        lgb = LGBMRegressor(random_state=0)

        params = {'n_estimators': [1000, 2000]}

        models = [xgb, gbm, lgb]
        best_models = []
        rmsles = []
        
        for model in models:
            new_model = self.best_params_model(model, params)[0]
            new_rmsle = self.best_params_model(model, params)[1]
            best_models.append(new_model)
            rmsles.append(new_rmsle)

        self.xgb_reg = best_models[0]
        self.gbm_reg = best_models[1]
        self.lgb_reg = best_models[1]

        self.xgb_rmsle = rmsles[0]
        self.gbm_rmsle = rmsles[1]
        self.lgb_rmsle = rmsles[1]

        xgb_pred = self.xgb_reg.predict(self.X_test)
        xgb_pred = np.expm1(xgb_pred)

        gbm_pred = self.gbm_reg.predict(self.X_test)
        gbm_pred = np.expm1(gbm_pred)

        lgb_pred = self.lgb_reg.predict(self.X_test)
        lgb_pred = np.expm1(lgb_pred)

        pred = np.array([xgb_pred, gbm_pred, lgb_pred])
        pred = np.transpose(pred)

        rmsle_sum = self.xgb_rmsle + self.gbm_rmsle + self.lgb_rmsle

        self.xgb_per = self.xgb_rmsle / rmsle_sum
        self.gbm_per = self.gbm_rmsle / rmsle_sum
        self.lgb_per = self.lgb_rmsle / rmsle_sum
        
        final = xgb_pred*self.xgb_per + gbm_pred*self.gbm_per + lgb_pred*self.lgb_per
        print("--final RSMLE--")
        self.rmsle(self.y_test, final)

    # making the prediction template about 03/04/07/2020
    def make_temp(self):
        CARD_SIDO_NMs = self.encoding_data['CARD_SIDO_NM'].unique()
        STD_CLSS_NMs  = self.encoding_data['STD_CLSS_NM'].unique()
        HOM_SIDO_NMs  = self.encoding_data['HOM_SIDO_NM'].unique()
        AGEs          = self.encoding_data['AGE'].unique()
        SEX_CTGO_CDs  = self.encoding_data['SEX_CTGO_CD'].unique()
        FLCs          = self.encoding_data['FLC'].unique()
        nums          = self.encoding_data['num'].unique()
        years         = [2020]
        months        = [4, 7]
        coronas       = self.encoding_data['corona'].unique()
        num_2020      = self.encoding_data['num_2020'].unique()

        comb_list = [CARD_SIDO_NMs, STD_CLSS_NMs,HOM_SIDO_NMs, AGEs, SEX_CTGO_CDs, FLCs, nums, years, months, coronas, num_2020]
        temp = np.array(list(product(*comb_list)))

        train_features = self.encoding_data.drop(['CSTMR_CNT', 'AMT', 'CNT'], axis=1)
        tmp = pd.DataFrame(data=temp, columns=train_features.columns)

        return tmp

    # making submission
    def make_sub(self, temp):
        xgb_pred = self.xgb_reg.predict(temp)
        xgb_pred = np.expm1(xgb_pred)

        gbm_pred = self.gbm_reg.predict(temp)
        gbm_pred = np.expm1(gbm_pred)

        lgb_pred = self.lgb_reg.predict(temp)
        lgb_pred = np.expm1(lgb_pred)

        final_rmsle = xgb_pred*self.xgb_per + gbm_pred*self.gbm_per + lgb_pred*self.lgb_per
        temp['AMT'] = np.round(final_rmsle, 0)
        temp['REG_YYMM'] = temp['year']*100 + temp['month']
        temp = temp[['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM', 'AMT']]
        temp = temp.groupby(['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM']).sum().reset_index(drop = False)

        temp['CARD_SIDO_NM'] = encoders['CARD_SIDO_NM'].inverse_transform(temp['CARD_SIDO_NM'])
        temp['STD_CLSS_NM'] = encoders['STD_CLSS_NM'].inverse_transform(temp['STD_CLSS_NM'])

        return temp

# %%
def sampling(sido):
    df = data[data['CARD_SIDO_NM']==sido]
    df = df.sample(n = 10000)
    return df

# %%
def grap_year(data):
    data = str(data)
    return int(data[:4])

def grap_month(data):
    data = str(data)
    return int(data[4:])

# %%
def grap_corona(data):
  corona = [202002, 202003, 202004]
  
  if data in corona:
    return 1
  else :
    return 0

# %%
def data_pre(data):
    data = data.fillna('')
    data['year'] = data['REG_YYMM'].apply(lambda x: grap_year(x))
    data['month'] = data['REG_YYMM'].apply(lambda x: grap_month(x))
    data['corona'] = data['REG_YYMM'].apply(lambda x: grap_corona(x))
    data = data.drop(['REG_YYMM'], axis = 1)

    return data

# %%
def encoding(data):

    global encoders
    dtypes = data.dtypes
    encoders = {}
    for column in data.columns:
        if str(dtypes[column]) == 'object':
            encoder = LabelEncoder()
            encoder.fit(data[column])
            encoders[column] = encoder

    data_num = data.copy()

    for column in encoders.keys():
        encoder = encoders[column]
        data_num[column] = encoder.transform(data[column])

    return data_num

# %%
def split(data_num):
    split_data = []

    X_data, y_data = data_num.loc[:, data_num.columns != 'AMT'], data_num['AMT']
    X_data = X_data.drop(['CSTMR_CNT', 'CNT'], axis=1)
    X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, random_state=126, shuffle=True)
    y_train = np.log1p(y_train)
    
    return X_train, X_test, y_train, y_test

# %%
# train 데이터 불러오기
train = pd.read_csv('/content/drive/My Drive/Colab Notebooks/jeju/201901-202003.csv')
# 시도별 예측 데이터 프레임 생성을 위한 시도 리스트 생성
sido_list = train['CARD_SIDO_NM'].unique().tolist()

# %%
data_2004 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/jeju/202004.csv')

# %%
data_2003 = train[train['REG_YYMM'] == 202003]

# %%
tmp03 = data_2003.groupby(['CARD_SIDO_NM', 'STD_CLSS_NM']).AMT.sum().reset_index()
tmp04 = data_2004.groupby(['CARD_SIDO_NM', 'STD_CLSS_NM']).AMT.sum().reset_index()
tmp = pd.merge(tmp03, tmp04, on = ['CARD_SIDO_NM', 'STD_CLSS_NM'])
tmp.columns = ['CARD_SIDO_NM', 'STD_CLSS_NM', 'AMT_03', 'AMT_04']
tmp
# Out:
#     CARD_SIDO_NM            STD_CLSS_NM       AMT_03       AMT_04
# 0             강원             건강보조식품 소매업     96059012     88823988
# 1             강원                골프장 운영업   2915797995   4708346820
# 2             강원            과실 및 채소 소매업    994816943   1121028924
# 3             강원      관광 민예품 및 선물용품 소매업     13317300     14360780
# 4             강원        그외 기타 스포츠시설 운영업      2075000       227200
# ..           ...                    ...          ...          ...
# 599           충북  피자 햄버거 샌드위치 및 유사 음식점업   1315245299   1373635928
# 600           충북                한식 음식점업  16152482704  18911036160
# 601           충북                    호텔업     15248550     14121500
# 602           충북          화장품 및 방향제 소매업    428881434    450507431
# 603           충북               휴양콘도 운영업     12733490      9328420
#
# [604 rows x 4 columns]

# %%
tmp['num'] = tmp.apply(lambda x: 1 if x['AMT_03'] < x['AMT_04'] else 0, axis = 1)
tmp
# Out:
#     CARD_SIDO_NM            STD_CLSS_NM       AMT_03       AMT_04  num
# 0             강원             건강보조식품 소매업     96059012     88823988    0
# 1             강원                골프장 운영업   2915797995   4708346820    1
# 2             강원            과실 및 채소 소매업    994816943   1121028924    1
# 3             강원      관광 민예품 및 선물용품 소매업     13317300     14360780    1
# 4             강원        그외 기타 스포츠시설 운영업      2075000       227200    0
# ..           ...                    ...          ...          ...  ...
# 599           충북  피자 햄버거 샌드위치 및 유사 음식점업   1315245299   1373635928    1
# 600           충북                한식 음식점업  16152482704  18911036160    1
# 601           충북                    호텔업     15248550     14121500    0
# 602           충북          화장품 및 방향제 소매업    428881434    450507431    1
# 603           충북               휴양콘도 운영업     12733490      9328420    0
#
# [604 rows x 5 columns]

# %%
data = train.copy()

# %%
data = pd.concat([data, data_2004])

data
# Out:
#          REG_YYMM CARD_SIDO_NM CARD_CCG_NM  ... CSTMR_CNT      AMT CNT
# 0          201901           강원         강릉시  ...         4   311200   4
# 1          201901           강원         강릉시  ...         7  1374500   8
# 2          201901           강원         강릉시  ...         6   818700   6
# 3          201901           강원         강릉시  ...         4  1717000   5
# 4          201901           강원         강릉시  ...         3  1047300   3
# ...           ...          ...         ...  ...       ...      ...  ..
# 1350317    202004           충북         충주시  ...         5    77000   5
# 1350318    202004           충북         충주시  ...         6    92000   6
# 1350319    202004           충북         충주시  ...         5   193000   5
# 1350320    202004           충북         충주시  ...         5    86000   7
# 1350321    202004           충북         충주시  ...         3   227000   4
#
# [26048114 rows x 12 columns]

# %%
data = data.merge(tmp[['CARD_SIDO_NM', 'STD_CLSS_NM', 'num']], how = 'left')

data
# Out:
#           REG_YYMM CARD_SIDO_NM CARD_CCG_NM  ...      AMT CNT  num
# 0           201901           강원         강릉시  ...   311200   4  0.0
# 1           201901           강원         강릉시  ...  1374500   8  0.0
# 2           201901           강원         강릉시  ...   818700   6  0.0
# 3           201901           강원         강릉시  ...  1717000   5  0.0
# 4           201901           강원         강릉시  ...  1047300   3  0.0
# ...            ...          ...         ...  ...      ...  ..  ...
# 26048109    202004           충북         충주시  ...    77000   5  0.0
# 26048110    202004           충북         충주시  ...    92000   6  0.0
# 26048111    202004           충북         충주시  ...   193000   5  0.0
# 26048112    202004           충북         충주시  ...    86000   7  0.0
# 26048113    202004           충북         충주시  ...   227000   4  0.0
#
# [26048114 rows x 13 columns]

# %%
data = data.fillna(0)
data['num'] = data['num'].apply(int)

# %%
std_num = pd.read_excel('/content/drive/My Drive/Colab Notebooks/jeju/소비패턴.xlsx', header = 1)
std_num.rename(columns = {'지역' : 'STD_CLSS_NM'}, inplace = True)

# %%
for sido in sido_list:
  temp = sampling(sido).reset_index(drop=True)

  temp = data_pre(temp)
  temp = temp.drop(['CARD_CCG_NM', 'HOM_CCG_NM'], axis=1)
  temp = temp.merge(std_num[['STD_CLSS_NM', sido]], how = 'left', on = 'STD_CLSS_NM')
  temp.rename(columns = {sido : 'num_2020'}, inplace = True)

  temp_num = encoding(temp)
  temp_data = split(temp_num)

  temp = Model(temp_data, temp_num)


  temp.get_model()

  temp_temp = temp.make_temp()

  temp_sub = temp.make_sub(temp_temp)

  globals()['sub_{}'.format(sido)] = temp_sub
# Out:
# [03:28:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:28:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:28:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:28:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:28:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:28:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:28:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:28:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:28:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:28:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:28:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.209
# [03:28:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:28:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:28:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:28:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:28:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:28:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:28:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:29:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:29:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:29:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:29:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.209
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.208
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.208
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.302
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.302
# --final RSMLE--
# Test Data RMSLE: 1.208
# [03:33:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:33:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:33:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:33:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:33:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:33:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:33:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:33:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:33:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:33:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.496
# [03:33:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:34:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:34:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:34:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:34:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:34:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:34:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:34:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:34:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:34:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:34:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.496
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.498
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.498
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.605
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.605
# --final RSMLE--
# Test Data RMSLE: 1.497
# [03:38:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:38:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:38:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:38:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:38:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:38:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:38:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:38:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:38:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:39:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:39:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.501
# [03:39:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:39:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:39:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:39:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:39:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:39:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:39:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:39:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:39:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:39:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:39:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.501
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.503
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.503
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.611
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.611
# --final RSMLE--
# Test Data RMSLE: 1.502
# [03:43:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:43:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:43:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:43:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:43:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:43:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:43:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:43:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:43:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:44:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:44:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.427
# [03:44:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:44:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:44:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:44:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:44:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:44:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:44:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:44:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:44:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:44:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:44:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.427
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.427
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.427
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.523
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.523
# --final RSMLE--
# Test Data RMSLE: 1.427
# [03:48:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:49:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:49:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:49:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:49:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:49:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:49:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:49:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:49:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:49:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:49:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 1.182
# [03:49:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:49:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:49:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:49:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:49:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:49:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:49:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:49:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:50:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:50:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:50:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 1.182
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 1.181
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 1.181
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.226
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.226
# --final RSMLE--
# Test Data RMSLE: 1.181
# [03:55:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:55:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:55:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:55:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:55:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:55:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:55:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:55:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:56:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:56:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:56:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.354
# [03:56:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:56:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:56:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:56:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:56:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:56:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:56:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:56:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:56:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:56:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:56:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.354
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.355
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.355
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.416
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.416
# --final RSMLE--
# Test Data RMSLE: 1.354
# [04:00:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:01:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:01:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:01:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:01:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:01:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:01:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:01:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:01:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:01:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:01:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.121
# [04:01:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:01:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:01:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:01:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:01:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:01:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:01:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:01:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:02:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:02:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:02:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.121
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.118
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.118
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.187
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.187
# --final RSMLE--
# Test Data RMSLE: 1.119
# [04:05:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:05:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:05:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:05:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:05:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:05:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:06:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:06:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:06:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:06:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:06:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.294
# [04:06:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:06:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:06:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:06:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:06:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:06:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:06:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:06:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:06:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:06:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:07:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.294
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.291
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.291
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.361
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.361
# --final RSMLE--
# Test Data RMSLE: 1.292
# [04:11:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:11:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:11:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:11:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:11:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:11:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:11:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:11:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:11:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:11:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:11:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.430
# [04:11:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:11:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:11:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:11:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:12:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:12:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:12:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:12:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:12:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:12:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:12:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.430
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.428
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.428
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.526
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.526
# --final RSMLE--
# Test Data RMSLE: 1.428
# [04:16:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:16:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:16:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:16:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:16:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:16:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:16:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:16:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:16:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:16:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:16:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 0.974
# [04:17:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:17:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:17:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:17:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:17:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:17:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:17:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:17:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:17:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:17:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:17:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 0.974
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 0.973
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 2000}
# Test Data RMSLE: 0.973
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.013
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.013
# --final RSMLE--
# Test Data RMSLE: 0.973
# [04:22:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:22:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:22:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:22:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:22:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:22:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:22:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:22:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:22:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:22:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:22:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.251
# [04:22:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:22:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:22:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:23:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:23:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:23:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:23:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:23:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:23:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:23:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:23:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.251
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.254
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.254
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.302
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.302
# --final RSMLE--
# Test Data RMSLE: 1.252
# [04:27:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:27:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:27:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:27:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:28:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:28:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:28:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:28:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:28:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:28:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:28:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.217
# [04:28:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:28:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:28:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:28:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:28:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:28:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:28:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:28:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:28:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:28:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:29:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.217
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.218
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.218
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.301
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.301
# --final RSMLE--
# Test Data RMSLE: 1.217
# [04:32:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:32:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:32:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:32:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:33:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:33:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:33:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:33:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:33:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:33:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:33:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.406
# [04:33:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:33:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:33:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:33:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:33:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:33:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:33:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:33:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:34:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:34:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.406
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.409
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.409
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.480
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.480
# --final RSMLE--
# Test Data RMSLE: 1.407
# [04:38:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:38:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:38:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:38:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:38:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:38:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:38:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:38:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:38:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:38:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:38:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.344
# [04:38:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:38:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:38:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:38:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:38:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:38:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:39:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:39:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:39:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:39:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:39:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.344
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.343
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.343
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.441
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.441
# --final RSMLE--
# Test Data RMSLE: 1.343
# [04:43:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:43:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:43:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:43:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:43:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:44:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:44:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:44:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:44:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:44:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:44:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.014
# [04:44:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:44:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:44:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:44:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:44:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:44:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:44:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:44:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:44:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:44:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:45:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.014
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.017
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.017
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.066
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.066
# --final RSMLE--
# Test Data RMSLE: 1.015
# [04:49:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:49:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:49:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:49:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:49:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:49:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:49:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:50:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:50:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:50:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:50:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.315
# [04:50:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:50:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:50:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:50:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:50:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:50:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:50:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:50:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:50:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:50:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:50:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.315
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.317
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.317
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.400
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.400
# --final RSMLE--
# Test Data RMSLE: 1.316
# [04:55:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:55:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:55:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:55:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:55:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:55:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:55:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:55:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:55:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:56:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:56:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.289
# [04:56:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:56:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:56:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:56:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:56:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:56:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:56:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:56:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:56:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:56:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:56:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---- XGBRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.289
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.285
# ---- GradientBoostingRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.285
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.372
# ---- LGBMRegressor ----
# GridSearchCV 최적 하이퍼 파라미터 : {'n_estimators': 1000}
# Test Data RMSLE: 1.372
# --final RSMLE--
# Test Data RMSLE: 1.286

# %%
for sido in sido_list:
  globals()['sub_{}'.format(sido)].to_json('/content/drive/My Drive/Colab Notebooks/jeju/final sub/'+sido+'.json', orient = 'table')

# %%
from numpy import inf

def sido_diff(sido):


  df = data[data['CARD_SIDO_NM'] == sido]
  df_19 = df[df['REG_YYMM'] == 201904]
  df_20 = df[df['REG_YYMM'] == 202004]
  diff = pd.concat([df_19.groupby('STD_CLSS_NM').AMT.sum(), df_20.groupby('STD_CLSS_NM').AMT.sum()], axis=1, keys = ['1904_AMT', '2004_AMT']).reset_index()
  diff = diff.fillna(0)
  diff['diff'] = (diff['1904_AMT']-diff['2004_AMT'])/diff['1904_AMT']
  diff['diff'] = diff['diff'].apply(lambda x: 0 if x == -inf else x)
  diff.columns = ['STD_CLSS_NM', '1904_AMT', '2004_AMT', 'diff']
  diff = diff[['STD_CLSS_NM', 'diff']]
  diff = diff.sort_values(by='diff', ascending=False).reset_index(drop=True)

  return diff

# %%
for sido in sido_list:
  tmp = sido_diff(sido)

  globals()['diff_{}'.format(sido)] = tmp

# %%
test_subs = [sub_강원, sub_경기, sub_경남, sub_경북, sub_광주, sub_대구, sub_대전, sub_부산, sub_서울, sub_세종, sub_울산, sub_인천, sub_전남, sub_전북, sub_제주, sub_충남, sub_충북]
test_diffs = [diff_강원, diff_경기, diff_경남, diff_경북, diff_광주, diff_대구, diff_대전, diff_부산, diff_서울, diff_세종, diff_울산, diff_인천, diff_전남, diff_전북, diff_제주, diff_충남, diff_충북]

# %%
subs = test_subs.copy()
diffs = test_diffs.copy()

# %%
for i in range(len(sido_list)):
  subs[i] = subs[i].merge(diffs[i][['STD_CLSS_NM','diff']], how='left', on='STD_CLSS_NM')
  subs[i]['AMT'] = subs[i]['AMT']*(1-subs[i]['diff'])
  subs[i] = subs[i][['REG_YYMM','CARD_SIDO_NM','STD_CLSS_NM','AMT']]

# %%
test = pd.concat(subs)
test = test.sort_values(by = ['REG_YYMM', 'CARD_SIDO_NM']).reset_index(drop = True)
test
# Out:
#       REG_YYMM CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0       202004           강원             건강보조식품 소매업  4.236833e+09
# 1       202004           강원                골프장 운영업  7.410128e+09
# 2       202004           강원            과실 및 채소 소매업  2.906536e+09
# 3       202004           강원      관광 민예품 및 선물용품 소매업  1.256560e+09
# 4       202004           강원        그외 기타 스포츠시설 운영업  5.742499e+07
# ...        ...          ...                    ...           ...
# 1225    202007           충북  피자 햄버거 샌드위치 및 유사 음식점업  7.067052e+08
# 1226    202007           충북                한식 음식점업  1.098161e+09
# 1227    202007           충북                    호텔업  3.919298e+08
# 1228    202007           충북          화장품 및 방향제 소매업  7.162347e+08
# 1229    202007           충북               휴양콘도 운영업  1.468913e+08
#
# [1230 rows x 4 columns]

# %%
project_id = 'jeju-bigquery-282708'
client = bigquery.Client(project = 'jeju-bigquery-282708')

submission = client.query('''
  SELECT 
    * 
  FROM `jeju-bigquery-282708.jeju_bigdata.submission` 
  ''').to_dataframe()

# %%
final = submission.drop(['AMT'], axis=1)
final = final.merge(test, on=['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM'], how='left')
final
# Out:
#         id  REG_YYMM CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0        0    202004           강원             건강보조식품 소매업  4.236833e+09
# 1        1    202004           강원                골프장 운영업  7.410128e+09
# 2        2    202004           강원            과실 및 채소 소매업  2.906536e+09
# 3        3    202004           강원      관광 민예품 및 선물용품 소매업  1.256560e+09
# 4        4    202004           강원   그외 기타 분류안된 오락관련 서비스업           NaN
# ...    ...       ...          ...                    ...           ...
# 1389  1389    202007           충북  피자 햄버거 샌드위치 및 유사 음식점업  7.067052e+08
# 1390  1390    202007           충북                한식 음식점업  1.098161e+09
# 1391  1391    202007           충북                    호텔업  3.919298e+08
# 1392  1392    202007           충북          화장품 및 방향제 소매업  7.162347e+08
# 1393  1393    202007           충북               휴양콘도 운영업  1.468913e+08
#
# [1394 rows x 5 columns]

# %%
final_nan = final[final['AMT'].isnull()].reset_index(drop=True)
final_nan
# Out:
#        id  REG_YYMM CARD_SIDO_NM           STD_CLSS_NM  AMT
# 0       4    202004           강원  그외 기타 분류안된 오락관련 서비스업  NaN
# 1      30    202004           강원             정기 항공 운송업  NaN
# 2      35    202004           강원                택시 운송업  NaN
# 3      45    202004           경기  그외 기타 분류안된 오락관련 서비스업  NaN
# 4      53    202004           경기             내항 여객 운송업  NaN
# ..    ...       ...          ...                   ...  ...
# 161  1368    202007           충북                버스 운송업  NaN
# 162  1376    202007           충북                  여행사업  NaN
# 163  1381    202007           충북               자동차 임대업  NaN
# 164  1383    202007           충북             정기 항공 운송업  NaN
# 165  1388    202007           충북                택시 운송업  NaN
#
# [166 rows x 5 columns]

# %%
nan = final_nan.copy()

# %% [markdown]
# 제주 빅데이터 콘테스트의 최종 목표는 기존에 채점되던 2020년 4월 데이터가 아닌, 2020년 7월 데이터를 예측하는 것이므로, 최종 제출 버전에는 2019년 7월 데이터를 기반으로 한 결측치 대체 과정을 실시함

# %%
train07 = train[train['REG_YYMM'] == 201907]
train07 = train07[['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM', 'AMT']]
train07
# Out:
#           REG_YYMM CARD_SIDO_NM STD_CLSS_NM      AMT
# 10010561    201907           강원  건강보조식품 소매업    77000
# 10010562    201907           강원  건강보조식품 소매업  1400000
# 10010563    201907           강원  건강보조식품 소매업   447500
# 10010564    201907           강원  건강보조식품 소매업  1612000
# 10010565    201907           강원  건강보조식품 소매업  4249550
# ...            ...          ...         ...      ...
# 11731909    201907           충북    휴양콘도 운영업   243650
# 11731910    201907           충북    휴양콘도 운영업   308000
# 11731911    201907           충북    휴양콘도 운영업   146700
# 11731912    201907           충북    휴양콘도 운영업    45000
# 11731913    201907           충북    휴양콘도 운영업    64000
#
# [1721353 rows x 4 columns]

# %%
train07 = train07.groupby(['REG_YYMM','CARD_SIDO_NM','STD_CLSS_NM']).AMT.sum().reset_index()

# %%
for i in range(len(sido_list)):
  tmp1 = train07[train07['CARD_SIDO_NM'] == sido_list[i]].merge(diffs[i], on = 'STD_CLSS_NM')
  tmp1['pred'] = tmp1['AMT']*(1-tmp1['diff'])
  globals()[sido_list[i]] = nan[nan['CARD_SIDO_NM'] == sido_list[i]].merge(tmp1[['STD_CLSS_NM', 'pred']], on = 'STD_CLSS_NM', how = 'left')

# %%
강원
# Out:
#     id  REG_YYMM CARD_SIDO_NM           STD_CLSS_NM  AMT           pred
# 0    4    202004           강원  그외 기타 분류안된 오락관련 서비스업  NaN            NaN
# 1   30    202004           강원             정기 항공 운송업  NaN            NaN
# 2   35    202004           강원                택시 운송업  NaN  129179.526677
# 3  701    202007           강원  그외 기타 분류안된 오락관련 서비스업  NaN            NaN
# 4  727    202007           강원             정기 항공 운송업  NaN            NaN
# 5  732    202007           강원                택시 운송업  NaN  129179.526677

# %%
n = pd.concat([강원, 경기, 경남, 경북, 광주, 대구, 대전, 부산, 서울, 세종, 울산, 인천, 전남, 전북, 제주, 충남, 충북])
n = n.drop(['AMT'], axis = 1)
n.rename(columns = {'pred':'AMT'}, inplace = True)
n = n.fillna(0)

# %%
n
# Out:
#       id  REG_YYMM CARD_SIDO_NM           STD_CLSS_NM            AMT
# 0      4    202004           강원  그외 기타 분류안된 오락관련 서비스업       0.000000
# 1     30    202004           강원             정기 항공 운송업       0.000000
# 2     35    202004           강원                택시 운송업  129179.526677
# 3    701    202007           강원  그외 기타 분류안된 오락관련 서비스업       0.000000
# 4    727    202007           강원             정기 항공 운송업       0.000000
# ..   ...       ...          ...                   ...            ...
# 7   1368    202007           충북                버스 운송업       0.000000
# 8   1376    202007           충북                  여행사업       0.000000
# 9   1381    202007           충북               자동차 임대업  325242.799394
# 10  1383    202007           충북             정기 항공 운송업       0.000000
# 11  1388    202007           충북                택시 운송업  573957.718121
#
# [166 rows x 5 columns]

# %%
amt_nan = []
for idx, x in final_nan.iterrows():
  amt = test[(test['CARD_SIDO_NM']==x['CARD_SIDO_NM']) & (test['STD_CLSS_NM']==x['STD_CLSS_NM'])]['AMT']
  amt_nan.append(amt)

# %%
amt_nan = pd.Series(amt_nan)
final_nan['AMT'] = amt_nan

# %%
final = final.dropna(subset=['AMT'])
final
# Out:
#         id  REG_YYMM CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0        0    202004           강원             건강보조식품 소매업  4.236833e+09
# 1        1    202004           강원                골프장 운영업  7.410128e+09
# 2        2    202004           강원            과실 및 채소 소매업  2.906536e+09
# 3        3    202004           강원      관광 민예품 및 선물용품 소매업  1.256560e+09
# 5        5    202004           강원        그외 기타 스포츠시설 운영업  5.742499e+07
# ...    ...       ...          ...                    ...           ...
# 1389  1389    202007           충북  피자 햄버거 샌드위치 및 유사 음식점업  7.067052e+08
# 1390  1390    202007           충북                한식 음식점업  1.098161e+09
# 1391  1391    202007           충북                    호텔업  3.919298e+08
# 1392  1392    202007           충북          화장품 및 방향제 소매업  7.162347e+08
# 1393  1393    202007           충북               휴양콘도 운영업  1.468913e+08
#
# [1228 rows x 5 columns]

# %%
final = pd.concat([final, n])
final = final.sort_values('id').reset_index(drop=True)

final
# Out:
#         id  REG_YYMM CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0        0    202004           강원             건강보조식품 소매업  4.236833e+09
# 1        1    202004           강원                골프장 운영업  7.410128e+09
# 2        2    202004           강원            과실 및 채소 소매업  2.906536e+09
# 3        3    202004           강원      관광 민예품 및 선물용품 소매업  1.256560e+09
# 4        4    202004           강원   그외 기타 분류안된 오락관련 서비스업  0.000000e+00
# ...    ...       ...          ...                    ...           ...
# 1389  1389    202007           충북  피자 햄버거 샌드위치 및 유사 음식점업  7.067052e+08
# 1390  1390    202007           충북                한식 음식점업  1.098161e+09
# 1391  1391    202007           충북                    호텔업  3.919298e+08
# 1392  1392    202007           충북          화장품 및 방향제 소매업  7.162347e+08
# 1393  1393    202007           충북               휴양콘도 운영업  1.468913e+08
#
# [1394 rows x 5 columns]

# %%
final['AMT'] = final['AMT'].astype(int)
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1394 entries, 0 to 1393
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1394 non-null   int64
#  1   REG_YYMM      1394 non-null   int64
#  2   CARD_SIDO_NM  1394 non-null   object
#  3   STD_CLSS_NM   1394 non-null   object
#  4   AMT           1394 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 54.6+ KB

# %%
final.to_csv('/content/drive/My Drive/Colab Notebooks/jeju/submission_real_final.csv', encoding='utf-8-sig', index=False)
